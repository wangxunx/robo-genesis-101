# %% [markdown]
# # L09 · 数据集解剖与模仿学习 101
#
# > 本 notebook 目前为规划中的结构骨架，用于固定双语课程结构；L09 的完整练习将在对应讲次开发阶段完成并验收。

# %%
from robo_genesis.course_manifest import load_course_manifest

lesson = load_course_manifest().lesson("L09")
assert lesson.status.value == "planned"
