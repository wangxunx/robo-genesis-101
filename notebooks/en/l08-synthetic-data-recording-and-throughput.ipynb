# %% [markdown]
# # L08 · Synthetic Data Recording and Collection Throughput
#
# > This notebook is currently a planned structural scaffold. The complete L08 exercises will be developed and reviewed during the corresponding lesson phase.

# %%
from robo_genesis.course_manifest import load_course_manifest

lesson = load_course_manifest().lesson("L08")
assert lesson.status.value == "planned"
