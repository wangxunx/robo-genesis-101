# %% [markdown]
# # L08 · 合成数据录制与采数吞吐
#
# > 本 notebook 目前为规划中的结构骨架，用于固定双语课程结构；L08 的完整练习将在对应讲次开发阶段完成并验收。

# %%
from robo_genesis.course_manifest import load_course_manifest

lesson = load_course_manifest().lesson("L08")
assert lesson.status.value == "planned"
