# %% [markdown]
# # L09 · Dataset Anatomy and Imitation Learning 101
#
# > This notebook is currently a planned structural scaffold. The complete L09 exercises will be developed and reviewed during the corresponding lesson phase.

# %%
from robo_genesis.course_manifest import load_course_manifest

lesson = load_course_manifest().lesson("L09")
assert lesson.status.value == "planned"
