# %% [markdown]
# # L07 · Demonstration Acquisition and Scripted Experts
#
# > This notebook has not been published yet. The complete exercises are still being prepared.

# %%
from robo_genesis.course_manifest import load_course_manifest

lesson = load_course_manifest().lesson("L07")
assert lesson.status.value == "planned"
